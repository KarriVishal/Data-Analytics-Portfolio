# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\visha\OneDrive\Data Analytics\pandas_project_dataset_500_rows.csv")
df
# Out:
#      Order_ID Customer_Name Product     Category  Quantity  Unit_Price  \
# 0        1001          Amit   Watch      Fashion         4        4500
# 1        1002         Sneha   Phone  Electronics         1       25000
# 2        1003          Ravi   Watch      Fashion         5        4500
# 3        1004         Priya   Chair    Furniture         4        3500
# 4        1005         Kiran  Laptop  Electronics         3       55000
# ..        ...           ...     ...          ...       ...         ...
# 495      1496         Arjun    Book        Books         5         500
# 496      1497          Neha   Watch      Fashion         2        4500
# 497      1498          Neha    Book        Books         3         500
# 498      1499         Kiran   Watch      Fashion         5        4500
# 499      1500         Kiran    Book        Books         2         500
#
#           City  Order_Date
# 0    Hyderabad  2025-08-14
# 1        Delhi  2025-10-19
# 2    Bangalore  2025-01-16
# ...

# %%
df.head(10)
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Unit_Price  \
# 0      1001          Amit       Watch      Fashion         4        4500
# 1      1002         Sneha       Phone  Electronics         1       25000
# 2      1003          Ravi       Watch      Fashion         5        4500
# 3      1004         Priya       Chair    Furniture         4        3500
# 4      1005         Kiran      Laptop  Electronics         3       55000
# 5      1006          Neha       Watch      Fashion         2        4500
# 6      1007         Arjun        Book        Books         3         500
# 7      1008         Priya       Watch      Fashion         2        4500
# 8      1009        Vishal       Phone  Electronics         4       25000
# 9      1010          Ravi  Headphones  Electronics         1        2000
#
#         City  Order_Date
# 0  Hyderabad  2025-08-14
# 1      Delhi  2025-10-19
# 2  Bangalore  2025-01-16
# 3     Mumbai  2025-06-28
# 4      Delhi  2025-11-11
# ...

# %%
#no of rows
df.shape[0]
# Out:
# 500

# %%
#no of columns
df.shape[1]
# Out:
# 8

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Product', 'Category', 'Quantity',
#        'Unit_Price', 'City', 'Order_Date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID          int64
# Customer_Name    object
# Product          object
# Category         object
# Quantity          int64
# Unit_Price        int64
# City             object
# Order_Date       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_Name    0
# Product          0
# Category         0
# Quantity         0
# Unit_Price       0
# City             0
# Order_Date       0
# dtype: int64

# %%
df[['Customer_Name','Product','Quantity','Unit_Price']]
# Out:
#     Customer_Name Product  Quantity  Unit_Price
# 0            Amit   Watch         4        4500
# 1           Sneha   Phone         1       25000
# 2            Ravi   Watch         5        4500
# 3           Priya   Chair         4        3500
# 4           Kiran  Laptop         3       55000
# ..            ...     ...       ...         ...
# 495         Arjun    Book         5         500
# 496          Neha   Watch         2        4500
# 497          Neha    Book         3         500
# 498         Kiran   Watch         5        4500
# 499         Kiran    Book         2         500
#
# [500 rows x 4 columns]

# %%
df.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Book          193
# Chair         194
# Headphones    187
# Laptop        188
# Phone         186
# Shoes         136
# Table         180
# Watch         229
# Name: Quantity, dtype: int64

# %%
df.groupby('Category')['Unit_Price'].mean()
# Out:
# Category
# Books            500.000000
# Electronics    27771.739130
# Fashion         3438.461538
# Furniture       4244.274809
# Name: Unit_Price, dtype: float64

# %%
df[(df['Quantity'] > 3) & (df['Unit_Price'] > 5000)]
# Out:
#      Order_ID Customer_Name Product     Category  Quantity  Unit_Price  \
# 8        1009        Vishal   Phone  Electronics         4       25000
# 10       1011         Kiran   Phone  Electronics         4       25000
# 13       1014         Kiran  Laptop  Electronics         5       55000
# 17       1018         Priya   Phone  Electronics         4       25000
# 37       1038        Vishal   Phone  Electronics         4       25000
# 57       1058          Amit   Phone  Electronics         5       25000
# 68       1069          Ravi   Phone  Electronics         4       25000
# 75       1076          Ravi  Laptop  Electronics         5       55000
# 88       1089         Kiran  Laptop  Electronics         5       55000
# 91       1092         Rahul   Phone  Electronics         5       25000
# 110      1111         Rahul  Laptop  Electronics         4       55000
# 121      1122          Amit   Phone  Electronics         5       25000
# ...

# %%
df.sort_values(by='Unit_Price',ascending=False)
# Out:
#      Order_ID Customer_Name Product     Category  Quantity  Unit_Price  \
# 167      1168         Arjun  Laptop  Electronics         4       55000
# 454      1455         Rahul  Laptop  Electronics         1       55000
# 337      1338         Kiran  Laptop  Electronics         3       55000
# 451      1452         Kiran  Laptop  Electronics         1       55000
# 358      1359         Arjun  Laptop  Electronics         3       55000
# ..        ...           ...     ...          ...       ...         ...
# 361      1362         Arjun    Book        Books         4         500
# 117      1118        Vishal    Book        Books         5         500
# 120      1121        Anjali    Book        Books         5         500
# 351      1352        Vishal    Book        Books         4         500
# 499      1500         Kiran    Book        Books         2         500
#
#           City  Order_Date
# 167       Pune  2025-10-25
# 454  Bangalore  2025-02-14
# 337  Hyderabad  2025-05-23
# ...

# %%
df['City'].value_counts().head(5)
# Out:
# City
# Hyderabad    90
# Bangalore    88
# Pune         83
# Delhi        81
# Mumbai       79
# Name: count, dtype: int64

# %%
df.assign(Total_Amount=df['Quantity'] * df['Unit_Price'])
# Out:
#      Order_ID Customer_Name Product     Category  Quantity  Unit_Price  \
# 0        1001          Amit   Watch      Fashion         4        4500
# 1        1002         Sneha   Phone  Electronics         1       25000
# 2        1003          Ravi   Watch      Fashion         5        4500
# 3        1004         Priya   Chair    Furniture         4        3500
# 4        1005         Kiran  Laptop  Electronics         3       55000
# ..        ...           ...     ...          ...       ...         ...
# 495      1496         Arjun    Book        Books         5         500
# 496      1497          Neha   Watch      Fashion         2        4500
# 497      1498          Neha    Book        Books         3         500
# 498      1499         Kiran   Watch      Fashion         5        4500
# 499      1500         Kiran    Book        Books         2         500
#
#           City  Order_Date  Total_Amount
# 0    Hyderabad  2025-08-14         18000
# ...

# %%
df.groupby('City')['Total_Amount'].sum()
# Out:
# City
# Bangalore    2480400
# Chennai      2961900
# Delhi        2670200
# Hyderabad    3403300
# Mumbai       3196900
# Pune         3602100
# Name: Total_Amount, dtype: int64

# %%
df.pivot_table(values='Total_Amount',index='Category',columns='City',aggfunc='sum')
# Out:
# City         Bangalore  Chennai    Delhi  Hyderabad   Mumbai     Pune
# Category
# Books            16500    29500    14500      15000    10000    11000
# Electronics    1907000  2642000  2133000    2736000  2798000  3148000
# Fashion         284400   108900   205200     316800   135900   224100
# Furniture       272500   181500   317500     335500   253000   219000

# %%
df.loc[df['Unit_Price'].idxmax()]
# Out:
# Order_ID                1005
# Customer_Name          Kiran
# Product               Laptop
# Category         Electronics
# Quantity                   3
# Unit_Price             55000
# City                   Delhi
# Order_Date        2025-11-11
# Total_Amount          165000
# Name: 4, dtype: object

# %%
df.loc[df['Unit_Price'].idxmin()]
# Out:
# Order_ID               1007
# Customer_Name         Arjun
# Product                Book
# Category              Books
# Quantity                  3
# Unit_Price              500
# City                Chennai
# Order_Date       2025-09-07
# Total_Amount           1500
# Name: 6, dtype: object

# %%
df.nlargest(10,'Total_Amount')
# Out:
#      Order_ID Customer_Name Product     Category  Quantity  Unit_Price  \
# 13       1014         Kiran  Laptop  Electronics         5       55000
# 75       1076          Ravi  Laptop  Electronics         5       55000
# 88       1089         Kiran  Laptop  Electronics         5       55000
# 184      1185          Neha  Laptop  Electronics         5       55000
# 196      1197         Rahul  Laptop  Electronics         5       55000
# 210      1211         Kiran  Laptop  Electronics         5       55000
# 213      1214          Neha  Laptop  Electronics         5       55000
# 227      1228          Ravi  Laptop  Electronics         5       55000
# 234      1235         Sneha  Laptop  Electronics         5       55000
# 236      1237         Arjun  Laptop  Electronics         5       55000
#
#           City  Order_Date  Total_Amount
# 13      Mumbai  2025-01-31        275000
# 75     Chennai  2025-11-26        275000
# 88   Hyderabad  2025-06-14        275000
# ...

# %% [markdown]
# ## Business Insights

# %% [raw]
# 1.Which city has the highest total sales
# Answer : Pune
# 2.Which city has the lowest total sales?
# Answer : Bangalore
# 3.Which product was ordered the most?
# Answer : Watch
# 4.Which product generated the highest revenue?
# Answer : Laptop
# 5.Which category generated the highest revenue?
# Answer : Electronics
# 6.Which category sold the highest quantity of products?
# Answer : Electronics
# 7.Which customer placed the highest number of orders?
# Answer : Rahul
# 8. Which customer spent the most money?
# Answer : Kiran
# 9. What is the average order value?
# Answer : 36629.6
# 10. What is the total revenue generated from all orders?
# Answer : 18314800
